# %%
import os

import sys  # <- This is necessary!

# os.chdir('C:\\Users\\Administrator\\Downloads\\ML Lab')
#sys.path.append(r'D:\anaconda\envs')
sys.path.append(r'D:\anaconda\envs')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score
from timeseires.utils.to_split import to_split
from timeseires.utils.multivariate_multi_step import multivariate_multi_step
from timeseires.utils.multivariate_single_step import multivariate_single_step
from timeseires.utils.univariate_multi_step import univariate_multi_step
from timeseires.utils.univariate_single_step import univariate_single_step
from timeseires.utils.CosineAnnealingLRS import CosineAnnealingLRS
from timeseires.callbacks.EpochCheckpoint import EpochCheckpoint
from tensorflow.keras.callbacks import ModelCheckpoint
from timeseires.callbacks.TrainingMonitor import TrainingMonitor
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import LSTM, Bidirectional, Add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D,TimeDistributed
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,MaxPooling1D,Concatenate,AveragePooling1D, GlobalMaxPooling1D, Input
from tensorflow.keras.models import Sequential,Model
import pandas as pd
import time, pickle
import numpy as np
import tensorflow.keras.backend as K
import tensorflow
from tensorflow.keras.layers import Input, Reshape, Lambda
from tensorflow.keras.layers import Layer, Flatten, LeakyReLU, concatenate, Dense
from tensorflow.keras.regularizers import l2
import glob
import h5py
import matplotlib.pyplot as plt
from keras.callbacks import Callback

# %%
#lookback = 24
model = None
start_epoch = 0
time_steps=24
num_features=21

# %%
def CNN():
    input_data = Input(shape=(time_steps, num_features))
    x1 = Conv1D(16, 2, activation="relu")(input_data)
    x2 = Conv1D(16, 2, activation="relu")(x1)
    flatten = Flatten()(x2)
    output_data = Dense(1)(flatten)
    model = Model(input_data, output_data)
    return model

# %%
model1 = CNN()
model1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 24, 21)]          0
#
#  conv1d (Conv1D)             (None, 23, 16)            688
#
#  conv1d_1 (Conv1D)           (None, 22, 16)            528
#
#  flatten (Flatten)           (None, 352)               0
#
#  dense (Dense)               (None, 1)                 353
#
# =================================================================
# Total params: 1,569
# Trainable params: 1,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
tensorflow.keras.utils.plot_model(model1 )

# %%
checkpoints = r'D:\anaconda\envs\lab8\checkpoint\\E1-cp-{epoch:04d}-loss{val_loss:.2f}.h5'
OUTPUT_PATH = r'D:\anaconda\envs\lab8\checkpoint'
FIG_PATH = os.path.sep.join([OUTPUT_PATH,"\history.png"])
JSON_PATH = os.path.sep.join([OUTPUT_PATH,"\history.json"])

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,TrainingMonitor1]

# %%
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model =CNN()
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] compiling model...

# %%
import os
path_dataset ='D:\\anaconda\\envs\\lab8\\AEP_hourly\\processed'
path_tr = os.path.join(path_dataset, 'AEP_train.csv')
df_tr = pd.read_csv(path_tr)
train_set = df_tr.iloc[:].values
path_v = os.path.join(path_dataset, 'AEP_validation.csv')
df_v = pd.read_csv(path_v)
validation_set = df_v.iloc[:].values 
path_te = os.path.join(path_dataset, 'AEP_test.csv')
df_te = pd.read_csv(path_te)
test_set = df_te.iloc[:].values 

path_scaler = os.path.join(path_dataset, 'AEP_Scaler.pkl')
scaler         = pickle.load(open(path_scaler, 'rb'))

train_set.shape, validation_set.shape, test_set.shape
# Out:
# D:\anaconda\envs\MLLAB\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.0.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ((84907, 21), (24259, 21), (12130, 21))

# %%
time_steps=24
num_features=21

# %%
start = time.time()
train_X , train_y = univariate_multi_step(train_set, time_steps, target_col=0,target_len=1)
validation_X, validation_y = univariate_multi_step(validation_set, time_steps, target_col=0,target_len=1)
test_X, test_y = univariate_multi_step(test_set, time_steps, target_col=0,target_len=1)
print('Time Consumed', time.time()-start, "sec")
# Out:
# Time Consumed 0.32604026794433594 sec

# %%
epochs = 60
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,verbose = verbose)
# Out:
# Epoch 1/60
# 2629/2653 [============================>.] - ETA: 0s - loss: 0.0446 - mae: 0.0446 - mape: 782.0860
# Epoch 1: val_loss improved from inf to 0.02556, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0001-loss0.03.h5
# 2653/2653 [==============================] - 6s 2ms/step - loss: 0.0445 - mae: 0.0445 - mape: 775.2161 - val_loss: 0.0256 - val_mae: 0.0256 - val_mape: 11.5330
# Epoch 2/60
# 2632/2653 [============================>.] - ETA: 0s - loss: 0.0222 - mae: 0.0222 - mape: 448.5714
# Epoch 2: val_loss improved from 0.02556 to 0.02030, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0002-loss0.02.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0222 - mae: 0.0222 - mape: 445.1476 - val_loss: 0.0203 - val_mae: 0.0203 - val_mape: 9.3754
# Epoch 3/60
# 2630/2653 [============================>.] - ETA: 0s - loss: 0.0167 - mae: 0.0167 - mape: 174.2331
# Epoch 3: val_loss improved from 0.02030 to 0.01860, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0003-loss0.02.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0167 - mae: 0.0167 - mape: 172.7961 - val_loss: 0.0186 - val_mae: 0.0186 - val_mape: 8.6248
# Epoch 4/60
# 2635/2653 [============================>.] - ETA: 0s - loss: 0.0142 - mae: 0.0142 - mape: 550.2043
# Epoch 4: val_loss improved from 0.01860 to 0.01334, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0004-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0142 - mae: 0.0142 - mape: 546.5940 - val_loss: 0.0133 - val_mae: 0.0133 - val_mape: 6.6063
# Epoch 5/60
# 2647/2653 [============================>.] - ETA: 0s - loss: 0.0121 - mae: 0.0121 - mape: 492.9639
# Epoch 5: val_loss improved from 0.01334 to 0.01135, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0005-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0121 - mae: 0.0121 - mape: 491.9375 - val_loss: 0.0114 - val_mae: 0.0114 - val_mape: 6.7142
# Epoch 6/60
# 2636/2653 [============================>.] - ETA: 0s - loss: 0.0112 - mae: 0.0112 - mape: 611.0271
# Epoch 6: val_loss improved from 0.01135 to 0.01020, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0006-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0112 - mae: 0.0112 - mape: 607.2335 - val_loss: 0.0102 - val_mae: 0.0102 - val_mape: 5.5217
# Epoch 7/60
# 2647/2653 [============================>.] - ETA: 0s - loss: 0.0106 - mae: 0.0106 - mape: 460.3153
# Epoch 7: val_loss did not improve from 0.01020
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0106 - mae: 0.0106 - mape: 459.3590 - val_loss: 0.0108 - val_mae: 0.0108 - val_mape: 6.2133
# Epoch 8/60
# 2641/2653 [============================>.] - ETA: 0s - loss: 0.0103 - mae: 0.0103 - mape: 619.0569
# Epoch 8: val_loss improved from 0.01020 to 0.00920, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0008-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0103 - mae: 0.0103 - mape: 616.3712 - val_loss: 0.0092 - val_mae: 0.0092 - val_mape: 5.0264
# Epoch 9/60
# 2630/2653 [============================>.] - ETA: 0s - loss: 0.0099 - mae: 0.0099 - mape: 460.2992
# Epoch 9: val_loss did not improve from 0.00920
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0099 - mae: 0.0099 - mape: 456.4240 - val_loss: 0.0102 - val_mae: 0.0102 - val_mape: 6.9639
# Epoch 10/60
# 2641/2653 [============================>.] - ETA: 0s - loss: 0.0098 - mae: 0.0098 - mape: 433.4769
# Epoch 10: val_loss did not improve from 0.00920
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0098 - mae: 0.0098 - mape: 431.6010 - val_loss: 0.0138 - val_mae: 0.0138 - val_mape: 6.9494
# Epoch 11/60
# 2648/2653 [============================>.] - ETA: 0s - loss: 0.0094 - mae: 0.0094 - mape: 606.0313
# Epoch 11: val_loss improved from 0.00920 to 0.00905, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0011-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0094 - mae: 0.0094 - mape: 604.9938 - val_loss: 0.0091 - val_mae: 0.0091 - val_mape: 6.2400
# Epoch 12/60
# 2636/2653 [============================>.] - ETA: 0s - loss: 0.0092 - mae: 0.0092 - mape: 767.9412
# Epoch 12: val_loss did not improve from 0.00905
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0092 - mae: 0.0092 - mape: 763.1678 - val_loss: 0.0092 - val_mae: 0.0092 - val_mape: 5.3409
# Epoch 13/60
# 2636/2653 [============================>.] - ETA: 0s - loss: 0.0090 - mae: 0.0090 - mape: 619.1548
# Epoch 13: val_loss improved from 0.00905 to 0.00898, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0013-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0090 - mae: 0.0090 - mape: 615.3101 - val_loss: 0.0090 - val_mae: 0.0090 - val_mape: 6.2064
# Epoch 14/60
# 2644/2653 [============================>.] - ETA: 0s - loss: 0.0088 - mae: 0.0088 - mape: 708.6907
# Epoch 14: val_loss improved from 0.00898 to 0.00824, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0014-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0088 - mae: 0.0088 - mape: 706.4122 - val_loss: 0.0082 - val_mae: 0.0082 - val_mape: 4.8317
# Epoch 15/60
# 2642/2653 [============================>.] - ETA: 0s - loss: 0.0089 - mae: 0.0089 - mape: 658.3989
# Epoch 15: val_loss did not improve from 0.00824
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0089 - mae: 0.0089 - mape: 655.7863 - val_loss: 0.0094 - val_mae: 0.0094 - val_mape: 5.7616
# Epoch 16/60
# 2647/2653 [============================>.] - ETA: 0s - loss: 0.0087 - mae: 0.0087 - mape: 551.9324
# Epoch 16: val_loss did not improve from 0.00824
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0087 - mae: 0.0087 - mape: 550.7811 - val_loss: 0.0091 - val_mae: 0.0091 - val_mape: 5.8782
# Epoch 17/60
# 2646/2653 [============================>.] - ETA: 0s - loss: 0.0087 - mae: 0.0087 - mape: 618.1535
# Epoch 17: val_loss did not improve from 0.00824
# 2653/2653 [==============================] - 6s 2ms/step - loss: 0.0087 - mae: 0.0087 - mape: 616.6328 - val_loss: 0.0085 - val_mae: 0.0085 - val_mape: 4.9515
# Epoch 18/60
# 2634/2653 [============================>.] - ETA: 0s - loss: 0.0087 - mae: 0.0087 - mape: 530.8207
# Epoch 18: val_loss improved from 0.00824 to 0.00812, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0018-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0087 - mae: 0.0087 - mape: 527.1265 - val_loss: 0.0081 - val_mae: 0.0081 - val_mape: 5.1072
# Epoch 19/60
# 2625/2653 [============================>.] - ETA: 0s - loss: 0.0086 - mae: 0.0086 - mape: 410.4022
# Epoch 19: val_loss did not improve from 0.00812
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0086 - mae: 0.0086 - mape: 406.1716 - val_loss: 0.0085 - val_mae: 0.0085 - val_mape: 5.5827
# Epoch 20/60
# 2643/2653 [============================>.] - ETA: 0s - loss: 0.0085 - mae: 0.0085 - mape: 456.3910
# Epoch 20: val_loss did not improve from 0.00812
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0085 - mae: 0.0085 - mape: 454.7569 - val_loss: 0.0100 - val_mae: 0.0100 - val_mape: 5.3210
# Epoch 21/60
# 2641/2653 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0084 - mape: 328.0860
# Epoch 21: val_loss did not improve from 0.00812
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0084 - mae: 0.0084 - mape: 326.6686 - val_loss: 0.0104 - val_mae: 0.0104 - val_mape: 6.4866
# Epoch 22/60
# 2642/2653 [============================>.] - ETA: 0s - loss: 0.0082 - mae: 0.0082 - mape: 479.6715
# Epoch 22: val_loss did not improve from 0.00812
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0082 - mae: 0.0082 - mape: 477.7722 - val_loss: 0.0088 - val_mae: 0.0088 - val_mape: 5.4866
# Epoch 23/60
# 2641/2653 [============================>.] - ETA: 0s - loss: 0.0082 - mae: 0.0082 - mape: 410.1053
# Epoch 23: val_loss did not improve from 0.00812
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0082 - mae: 0.0082 - mape: 408.3284 - val_loss: 0.0090 - val_mae: 0.0090 - val_mape: 5.7738
# Epoch 24/60
# 2626/2653 [============================>.] - ETA: 0s - loss: 0.0082 - mae: 0.0082 - mape: 527.7280
# Epoch 24: val_loss did not improve from 0.00812
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0082 - mae: 0.0082 - mape: 522.4735 - val_loss: 0.0084 - val_mae: 0.0084 - val_mape: 5.1824
# Epoch 25/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0081 - mae: 0.0081 - mape: 447.1348
# Epoch 25: val_loss improved from 0.00812 to 0.00799, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0025-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0081 - mae: 0.0081 - mape: 447.1348 - val_loss: 0.0080 - val_mae: 0.0080 - val_mape: 5.3308
# Epoch 26/60
# 2624/2653 [============================>.] - ETA: 0s - loss: 0.0080 - mae: 0.0080 - mape: 500.4948
# Epoch 26: val_loss improved from 0.00799 to 0.00743, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0026-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0080 - mae: 0.0080 - mape: 495.1309 - val_loss: 0.0074 - val_mae: 0.0074 - val_mape: 5.2118
# Epoch 27/60
# 2634/2653 [============================>.] - ETA: 0s - loss: 0.0080 - mae: 0.0080 - mape: 572.2360
# Epoch 27: val_loss did not improve from 0.00743
# 2653/2653 [==============================] - 6s 2ms/step - loss: 0.0080 - mae: 0.0080 - mape: 568.2474 - val_loss: 0.0077 - val_mae: 0.0077 - val_mape: 4.8416
# Epoch 28/60
# 2650/2653 [============================>.] - ETA: 0s - loss: 0.0081 - mae: 0.0081 - mape: 531.5701
# Epoch 28: val_loss did not improve from 0.00743
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0081 - mae: 0.0081 - mape: 531.0588 - val_loss: 0.0078 - val_mae: 0.0078 - val_mape: 5.2067
# Epoch 29/60
# 2650/2653 [============================>.] - ETA: 0s - loss: 0.0080 - mae: 0.0080 - mape: 475.6378
# Epoch 29: val_loss did not improve from 0.00743
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0080 - mae: 0.0080 - mape: 475.1807 - val_loss: 0.0076 - val_mae: 0.0076 - val_mape: 4.6473
# Epoch 30/60
# 2642/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 525.6328
# Epoch 30: val_loss improved from 0.00743 to 0.00717, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0030-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 523.5494 - val_loss: 0.0072 - val_mae: 0.0072 - val_mape: 4.6952
# Epoch 31/60
# 2640/2653 [============================>.] - ETA: 0s - loss: 0.0080 - mae: 0.0080 - mape: 534.0171
# Epoch 31: val_loss did not improve from 0.00717
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0080 - mae: 0.0080 - mape: 531.5002 - val_loss: 0.0078 - val_mae: 0.0078 - val_mape: 4.9760
# Epoch 32/60
# 2631/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 474.7965
# Epoch 32: val_loss did not improve from 0.00717
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 470.9613 - val_loss: 0.0084 - val_mae: 0.0084 - val_mape: 5.1755
# Epoch 33/60
# 2643/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 513.2952
# Epoch 33: val_loss did not improve from 0.00717
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 511.4532 - val_loss: 0.0082 - val_mae: 0.0082 - val_mape: 4.7454
# Epoch 34/60
# 2633/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 521.5088
# Epoch 34: val_loss did not improve from 0.00717
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 517.6804 - val_loss: 0.0081 - val_mae: 0.0081 - val_mape: 5.2193
# Epoch 35/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 514.8915
# Epoch 35: val_loss did not improve from 0.00717
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 514.8915 - val_loss: 0.0072 - val_mae: 0.0072 - val_mape: 4.4821
# Epoch 36/60
# 2641/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 391.3033
# Epoch 36: val_loss did not improve from 0.00717
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 389.6100 - val_loss: 0.0075 - val_mae: 0.0075 - val_mape: 4.4877
# Epoch 37/60
# 2626/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 674.0051
# Epoch 37: val_loss did not improve from 0.00717
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 667.2822 - val_loss: 0.0077 - val_mae: 0.0077 - val_mape: 4.8966
# Epoch 38/60
# 2647/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 569.4310
# Epoch 38: val_loss improved from 0.00717 to 0.00711, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0038-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 568.2419 - val_loss: 0.0071 - val_mae: 0.0071 - val_mape: 4.6471
# Epoch 39/60
# 2625/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 632.3419
# Epoch 39: val_loss did not improve from 0.00711
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 625.8009 - val_loss: 0.0091 - val_mae: 0.0091 - val_mape: 5.9121
# Epoch 40/60
# 2639/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 573.1569
# Epoch 40: val_loss did not improve from 0.00711
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 570.2405 - val_loss: 0.0084 - val_mae: 0.0084 - val_mape: 5.2535
# Epoch 41/60
# 2642/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 541.3734
# Epoch 41: val_loss did not improve from 0.00711
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 539.2277 - val_loss: 0.0081 - val_mae: 0.0081 - val_mape: 4.7912
# Epoch 42/60
# 2620/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 623.7759
# Epoch 42: val_loss did not improve from 0.00711
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 616.1489 - val_loss: 0.0081 - val_mae: 0.0081 - val_mape: 4.9568
# Epoch 43/60
# 2627/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 459.9431
# Epoch 43: val_loss did not improve from 0.00711
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 455.5333 - val_loss: 0.0088 - val_mae: 0.0088 - val_mape: 5.2904
# Epoch 44/60
# 2634/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 581.2453
# Epoch 44: val_loss did not improve from 0.00711
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 577.1947 - val_loss: 0.0074 - val_mae: 0.0074 - val_mape: 4.7255
# Epoch 45/60
# 2625/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 585.9437
# Epoch 45: val_loss did not improve from 0.00711
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 579.8801 - val_loss: 0.0076 - val_mae: 0.0076 - val_mape: 4.7848
# Epoch 46/60
# 2653/2653 [==============================] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 545.6300
# Epoch 46: val_loss improved from 0.00711 to 0.00704, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0046-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 545.6300 - val_loss: 0.0070 - val_mae: 0.0070 - val_mape: 4.7619
# Epoch 47/60
# 2628/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 564.4980
# Epoch 47: val_loss did not improve from 0.00704
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 559.2943 - val_loss: 0.0073 - val_mae: 0.0073 - val_mape: 4.5084
# Epoch 48/60
# 2624/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 602.5643
# Epoch 48: val_loss did not improve from 0.00704
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 596.1041 - val_loss: 0.0071 - val_mae: 0.0071 - val_mape: 4.4472
# Epoch 49/60
# 2646/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 586.4256
# Epoch 49: val_loss did not improve from 0.00704
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 584.9811 - val_loss: 0.0077 - val_mae: 0.0077 - val_mape: 5.1216
# Epoch 50/60
# 2650/2653 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0077 - mape: 608.9930
# Epoch 50: val_loss did not improve from 0.00704
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0077 - mae: 0.0077 - mape: 608.4072 - val_loss: 0.0072 - val_mae: 0.0072 - val_mape: 4.6868
# Epoch 51/60
# 2643/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 610.6791
# Epoch 51: val_loss improved from 0.00704 to 0.00685, saving model to D:\anaconda\envs\lab8\checkpoint\E1-cp-0051-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 608.4883 - val_loss: 0.0069 - val_mae: 0.0069 - val_mape: 4.3031
# Epoch 52/60
# 2643/2653 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0077 - mape: 481.9326
# Epoch 52: val_loss did not improve from 0.00685
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 480.2052 - val_loss: 0.0088 - val_mae: 0.0088 - val_mape: 4.8938
# Epoch 53/60
# 2637/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 624.6748
# Epoch 53: val_loss did not improve from 0.00685
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 621.0255 - val_loss: 0.0082 - val_mae: 0.0082 - val_mape: 4.8345
# Epoch 54/60
# 2619/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 571.0652
# Epoch 54: val_loss did not improve from 0.00685
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 563.8712 - val_loss: 0.0077 - val_mae: 0.0077 - val_mape: 5.1852
# Epoch 55/60
# 2637/2653 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0077 - mape: 529.7617
# Epoch 55: val_loss did not improve from 0.00685
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0077 - mae: 0.0077 - mape: 526.6677 - val_loss: 0.0072 - val_mae: 0.0072 - val_mape: 4.9010
# Epoch 56/60
# 2622/2653 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0079 - mape: 702.2015
# Epoch 56: val_loss did not improve from 0.00685
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0079 - mae: 0.0079 - mape: 694.1385 - val_loss: 0.0070 - val_mae: 0.0070 - val_mape: 4.6478
# Epoch 57/60
# 2648/2653 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0077 - mape: 619.8694
# Epoch 57: val_loss did not improve from 0.00685
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0077 - mae: 0.0077 - mape: 618.8063 - val_loss: 0.0076 - val_mae: 0.0076 - val_mape: 4.6687
# Epoch 58/60
# 2625/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 536.4056
# Epoch 58: val_loss did not improve from 0.00685
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 530.8610 - val_loss: 0.0072 - val_mae: 0.0072 - val_mape: 4.7143
# Epoch 59/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0077 - mape: 558.4324
# Epoch 59: val_loss did not improve from 0.00685
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0077 - mae: 0.0077 - mape: 558.3146 - val_loss: 0.0076 - val_mae: 0.0076 - val_mape: 4.7836
# Epoch 60/60
# 2652/2653 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0078 - mape: 567.2570
# Epoch 60: val_loss did not improve from 0.00685
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0078 - mae: 0.0078 - mape: 567.1372 - val_loss: 0.0074 - val_mae: 0.0074 - val_mape: 4.7138

# %%
model = load_model(r'D:\anaconda\envs\lab8\checkpoint\E1-cp-0051-loss0.01.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 379/379 [==============================] - 1s 1ms/step
# Mean Absolute Error (MAE): 109.49
# Median Absolute Error (MedAE): 84.72
# Mean Squared Error (MSE): 21534.71
# Root Mean Squared Error (RMSE): 146.75
# Mean Absolute Percentage Error (MAPE): 0.75 %
# Median Absolute Percentage Error (MDAPE): 0.59 %
#
#
# y_test_unscaled.shape=  (12105, 1)
# y_pred.shape=  (12105, 1)

# %%
checkpoints = r'D:\anaconda\envs\lab8\checkpoint\E2-cp-{epoch:04d}-loss{val_loss:.2f}.h5'
model=r'D:\anaconda\envs\lab8\checkpoint\E1-cp-0051-loss0.01.h5'
start_epoch= 52

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,TrainingMonitor1]
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model = PC.build(time_steps=24, num_features=21, reg=0.0005)
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] loading D:\anaconda\envs\lab8\checkpoint\E1-cp-0051-loss0.01.h5...
# [INFO] old learning rate: 0.0010000000474974513
# [INFO] new learning rate: 9.999999747378752e-05

# %%
epochs = 10
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,
                        verbose = verbose)
# Out:
# Epoch 1/10
# 2635/2653 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0064 - mape: 526.4000
# Epoch 1: val_loss improved from inf to 0.00653, saving model to D:\anaconda\envs\lab8\checkpoint\E2-cp-0001-loss0.01.h5
# 2653/2653 [==============================] - 6s 2ms/step - loss: 0.0064 - mae: 0.0064 - mape: 522.9287 - val_loss: 0.0065 - val_mae: 0.0065 - val_mape: 3.9676
# Epoch 2/10
# 2628/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 475.1625
# Epoch 2: val_loss improved from 0.00653 to 0.00626, saving model to D:\anaconda\envs\lab8\checkpoint\E2-cp-0002-loss0.01.h5
# 2653/2653 [==============================] - 6s 2ms/step - loss: 0.0063 - mae: 0.0063 - mape: 470.7823 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 3.8090
# Epoch 3/10
# 2644/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 452.7599
# Epoch 3: val_loss did not improve from 0.00626
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0063 - mae: 0.0063 - mape: 451.3055 - val_loss: 0.0066 - val_mae: 0.0066 - val_mape: 3.6947
# Epoch 4/10
# 2643/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 430.6422
# Epoch 4: val_loss did not improve from 0.00626
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0063 - mae: 0.0063 - mape: 429.0968 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 3.5589
# Epoch 5/10
# 2643/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 404.5699
# Epoch 5: val_loss did not improve from 0.00626
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0063 - mae: 0.0063 - mape: 403.1185 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 3.5378
# Epoch 6/10
# 2628/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 384.6663
# Epoch 6: val_loss did not improve from 0.00626
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0063 - mae: 0.0063 - mape: 381.1322 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 3.5144
# Epoch 7/10
# 2651/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 368.8837
# Epoch 7: val_loss improved from 0.00626 to 0.00625, saving model to D:\anaconda\envs\lab8\checkpoint\E2-cp-0007-loss0.01.h5
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0063 - mae: 0.0063 - mape: 368.6673 - val_loss: 0.0063 - val_mae: 0.0063 - val_mape: 3.3876
# Epoch 8/10
# 2646/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 378.7213
# Epoch 8: val_loss improved from 0.00625 to 0.00618, saving model to D:\anaconda\envs\lab8\checkpoint\E2-cp-0008-loss0.01.h5
# 2653/2653 [==============================] - 6s 2ms/step - loss: 0.0063 - mae: 0.0063 - mape: 377.7892 - val_loss: 0.0062 - val_mae: 0.0062 - val_mape: 3.2976
# Epoch 9/10
# 2646/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 360.6609
# Epoch 9: val_loss did not improve from 0.00618
# 2653/2653 [==============================] - 6s 2ms/step - loss: 0.0063 - mae: 0.0063 - mape: 359.7752 - val_loss: 0.0065 - val_mae: 0.0065 - val_mape: 3.4314
# Epoch 10/10
# 2635/2653 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0063 - mape: 319.7464
# Epoch 10: val_loss did not improve from 0.00618
# 2653/2653 [==============================] - 5s 2ms/step - loss: 0.0063 - mae: 0.0063 - mape: 317.6429 - val_loss: 0.0065 - val_mae: 0.0065 - val_mape: 3.3454

# %%
model = load_model(r'D:\anaconda\envs\lab8\checkpoint\E1-cp-0051-loss0.01.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 379/379 [==============================] - 0s 1ms/step
# Mean Absolute Error (MAE): 109.49
# Median Absolute Error (MedAE): 84.72
# Mean Squared Error (MSE): 21534.71
# Root Mean Squared Error (RMSE): 146.75
# Mean Absolute Percentage Error (MAPE): 0.75 %
# Median Absolute Percentage Error (MDAPE): 0.59 %
#
#
# y_test_unscaled.shape=  (12105, 1)
# y_pred.shape=  (12105, 1)

# %% [markdown]
# # lab report

# %% [markdown]
# ## Lab 1
